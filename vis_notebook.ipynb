# %%
from analysis.network_analysis import *

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## PROJECTION COMPARISION

# %% [markdown]
# #### MNIST MLP

# %%
compare_projections(DataType.MNIST, 'mnist_mlp', 4, 0)

# %% [markdown]
# #### MNIST CNN

# %%
compare_projections(DataType.MNIST, 'mnist_cnn', 2, 0)

# %% [markdown]
# #### CIFAR MLP

# %%
compare_projections(DataType.CIFAR, 'cifar_mlp', 4, 0)

# %% [markdown]
# #### CIFAR CNN

# %%
compare_projections(DataType.CIFAR, 'cifar_cnn', 2, 0)

# %% [markdown]
# ## DISCRIMINATIVE MAP COMPARISION

# %% [markdown]
# #### MNIST MLP

# %%
compare_discriminative_map(DataType.MNIST, 'mnist_mlp', 4, 2000)
# Out:
# Metal device set to: Apple M1
# 2022-06-14 01:18:04.539006: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-14 01:18:04.539314: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# #### MNIST CNN

# %%
compare_discriminative_map(DataType.MNIST, 'mnist_cnn', 2, 2000)

# %% [markdown]
# #### CIFAR MLP

# %%
compare_discriminative_map(DataType.CIFAR, 'cifar_mlp', 4, 2000)

# %% [markdown]
# #### CIFAR CNN

# %%
compare_discriminative_map(DataType.CIFAR, 'cifar_cnn', 2, 2000)

# %% [markdown]
# ## INTER-LAYER EVOLUTION

# %%
points_lst = []
for n_layer in [n for n in range(4)]:
    points, targets = show_seq_projections(DataType.MNIST, 'mnist_mlp', n_layer, 100, 2000)
    points_lst.append(points)

# %%
inter_layer_evolution(points_lst, targets)

# %% [markdown]
# ## INTER-EPOCH EVOLUTION

# %%
activations, targets = get_all_activations(DataType.MNIST, 'mnist_mlp', 4, 2000)

# %%
points_lst, targets = process_activations(activations, targets, 2000)

# %%
inter_epoch_evolution(points_lst, targets)
